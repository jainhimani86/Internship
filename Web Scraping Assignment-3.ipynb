# %%
import numpy as np
import re
import pandas as pd
from selenium import webdriver
from selenium.webdriver.common.by import By
import warnings
warnings.filterwarnings('ignore')
import time
from selenium.common.exceptions import StaleElementReferenceException,NoSuchElementException
import requests

# %% [markdown]
# Solution 1

# %%
driver=webdriver.Chrome()

# %%
driver.get('https://www.amazon.in/')

# %%
item=input("Enter your item= ")
# Out:
# Enter your item= guitar

# %%
jobtitle=driver.find_element(By.XPATH,'/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[2]/div[1]/input')
jobtitle.send_keys(item)

# %%
searchbutton=driver.find_element(By.XPATH,'/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[3]/div/span/input')
searchbutton.click()
time.sleep(3)

# %% [markdown]
# Solution 2

# %%
product_name=[]
product_url=[]

# %%
start=0
end=3
for page in range(start,end):
    producttag=driver.find_elements(By.XPATH,'//div[@class="a-section a-spacing-small puis-padding-left-small puis-padding-right-small"]/div/h2/a/span')
    for i in producttag:
        product_name.append(i.text)
    next_button=driver.find_elements(By.XPATH,'/html/body/div[1]/div[1]/div[1]/div[1]/div/span[1]/div[1]/div[69]/div/div/span/a[3]')

# %%
start=0
end=3
for page in range(start,end):
    urltag=driver.find_elements(By.XPATH,'//div[@class="a-section a-spacing-none a-spacing-top-small s-title-instructions-style"]/h2/a')
    for i in urltag:
        product_url.append(i.get_attribute('href'))
    next_button=driver.find_elements(By.XPATH,'/html/body/div[1]/div[1]/div[1]/div[1]/div/span[1]/div[1]/div[69]/div/div/span/a[3]')

# %%
brand_name=[]
exchange=[]
price=[]
delivery=[]
availability=[]
for i in product_url:
    driver.get(i)
    time.sleep(5)
    
    try:
        availtag=driver.find_element(By.XPATH,'/html/body/div[2]/div/div[5]/div[3]/div[1]/div[3]/div/div[1]/div/div/div/form/div/div/div/div/div[4]/div/div[5]/div/div[1]/span')
        availability.append(availtag.text)
    except NoSuchElementException:
        availability.append('-')
        
        
    try:
        delivertag=driver.find_element(By.XPATH,'/html/body/div[2]/div/div[5]/div[3]/div[1]/div[3]/div/div[1]/div/div/div/form/div/div/div/div/div[4]/div/div[3]/div[10]/div[1]/div/div/div/span/span[1]')
        delivery.append(delivertag.text)
    except NoSuchElementException:
        delivery.append('-')
        
        
    
    try:
        pricetag=driver.find_element(By.XPATH,'/html/body/div[2]/div/div[5]/div[3]/div[4]/div[13]/div/div/div[4]/div[1]/span[3]/span[2]/span[2]')
        price.append(pricetag.text)
    except NoSuchElementException:
        price.append('-')
        
        
    
    try:
        brandtag=driver.find_element(By.XPATH,'/html/body/div[2]/div/div[5]/div[3]/div[4]/div[48]/div/table/tbody/tr[1]/td[2]/span')
        brand_name.append(brandtag.text)
    except NoSuchElementException:
        brand_name.append('-')
        
        
        
        
    try:
        exchtag=driver.find_element(By.XPATH,'/html/body/div[2]/div/div[5]/div[3]/div[4]/div[24]/div[2]/div/div/div/div[2]/div/ol/li[3]/div/span/div[2]/span')
        exchange.append(exchtag.text)
    except NoSuchElementException:
        exchange.append('-')

# %%
len(availability),len(brand_name),len(price),len(exchange),len(delivery),len(product_name),len(product_url)
# Out:
# (210, 210, 210, 210, 210, 210, 210)

# %%
df=pd.DataFrame({"Product Name":product_name,"Brand":brand_name,'Price':price,'Avialability':availability,'Delivery':delivery,'Exchange':exchange,'Product Url':product_url})

# %%
df
# Out:
#                                           Product Name         Brand  Price  \
# 0    Intern Int-38c Sunburst Linden Wood Acoustic G...        Intern  1,799
# 1    Kadence Frontier guitar with Online Guitar lea...       Kadence  4,499
# 2    Kadence rosewood Guitar Frontier Series, Elect...       Kadence  5,499
# 3    MOCKING BIRD 38 inch Acoustic Guitar for Begin...  MOCKING BIRD  3,179
# 4    Juârez Acoustic Guitar Kit, 38 Inch Cutaway, 0...        JUAREZ  1,949
# ..                                                 ...           ...    ...
# 205  Kadence Frontier guitar with Online Guitar lea...       Kadence  4,499
# 206  Juârez JRZ38C/WH 6 Strings Acoustic Guitar 38 ...        JUAREZ  1,739
# 207  Kadence rosewood Guitar Frontier Series, Elect...       Kadence  5,499
# 208                                                          Kadence  9,999
# 209                                                                -      -
#
# ...

# %% [markdown]
# Solution 3

# %%
driver=webdriver.Chrome()

# %%
driver.get('https://images.google.com/')

# %%
text=driver.find_element(By.XPATH,'/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div/div[2]/textarea')
text.send_keys('cars')

# %%
button=driver.find_element(By.XPATH,'/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/button')
button.click()

# %%
for _ in range(20):
    driver.execute_script("window.scrollBy(0,500)")

imageurls=[]
images=driver.find_elements(By.XPATH,'//img[@class="rg_i Q4LuWd"]')
for image in images:
    source=image.get_attribute('src')
    if source is not None:
        if(source[0:4]=='http'):
            imageurls.append(source)
            
            
for i in range(len(imageurls)):
    if i >10:
        breakBy.XPATH,
        print("Downloading {0} of {1} images".format(i,10))
        response=requests.get(imageurls[i])
        file=open(r"C:\Users\siddh\Desktop\sid\fliprobo"+str(i)+".jpg","wb")
        file.write(response.content)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[77], line 15
#      13 for i in range(len(imageurls)):
#      14     if i >10:
# ---> 15         breakBy.XPATH,
#      16         print("Downloading {0} of {1} images".format(i,10))
#      17         response=requests.get(imageurls[i])
#
# NameError: name 'breakBy' is not defined

# %%
imageurls
# Out:
# ['https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSyuhhfKQKrxn9-NMcY2M6TZ7WZ6v1bOV4qtw&usqp=CAU',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSxpMQ0UjuN63hb9KkHPO4Cdvr0Ea_KnucCbw&usqp=CAU',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTJpqpEX6fDzbjeDGj_C9kwYfTmu6vd42YjOw&usqp=CAU',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSfjUWqij4R4ncXzVQvY-ktVv7j66XORoXioQ&usqp=CAU',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQvlU1EPvFsnxajWjn8Ys0KNiphTHKkY7TXdA&usqp=CAU',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQnNwGydNMG6F3AtEs5nLx4yDejR3ALDE-erQ&usqp=CAU',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcRln-3kdi7WJ5fhB7DSmh_T_k_B5PbqJwVr6g&usqp=CAU',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQZEMaK3viYGfU36dYZv0GNuiw-kLECKoo9Yw&usqp=CAU',
#  'https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTIS2FO9y6dFJDfCdzNtJb-v_QyiwQoUQnJhw&usqp=CAU',
# ...

# %% [markdown]
# Solution 4

# %%
driver=webdriver.Chrome()

# %%
driver.get('http://www.flipkart.com/')

# %%
search=driver.find_element(By.XPATH,'/html/body/div[1]/div/div[1]/div/div/div/div/div[1]/div/div[1]/div/div[1]/div[1]/header/div[1]/div[2]/form/div/div/input')
search.send_keys('oneplus nord')

# %%
button=driver.find_element(By.XPATH,'/html/body/div[1]/div/div[1]/div/div/div/div/div[1]/div/div[1]/div/div[1]/div[1]/header/div[1]/div[2]/form/div/button')
button.click()

# %%
smartphone=[]
colour=[]
ramrom=[]
camera=[]
display=[]
battery=[]
price=[]
producturl=[]

# %%
urltag=driver.find_elements(By.XPATH,'//div[@class="_2kHMtA"]/a')
for i in urltag:
        producturl.append(i.get_attribute('href'))

# %%
smartphonetag=driver.find_elements(By.XPATH,'//div[@class="_4rR01T"]')
for i in smartphonetag:
    smartphone.append(i.text)

# %%
ramromtag=driver.find_elements(By.XPATH,'//div[@class="fMghEO"]/ul/li[1]')
for i in ramromtag:
    ramrom.append(i.text)

# %%
displaytag=driver.find_elements(By.XPATH,'//div[@class="fMghEO"]/ul/li[2]')
for i in displaytag:
    display.append(i.text)

# %%
cameratag=driver.find_elements(By.XPATH,'//div[@class="fMghEO"]/ul/li[3]')
for i in cameratag:
    camera.append(i.text)

# %%
batterytag=driver.find_elements(By.XPATH,'//div[@class="fMghEO"]/ul/li[4]')
for i in batterytag:
    battery.append(i.text)

# %%
pricetag=driver.find_elements(By.XPATH,'//div[@class="_30jeq3 _1_WHN1"]')
for i in pricetag:
    price.append(i.text)

# %%
for i in producturl:
    driver.get(i)
    time.sleep(5)
    
    try:
        colourtag=driver.find_element(By.XPATH,'//*[@id="container"]/div/div[3]/div[1]/div[2]/div[8]/div[4]/div/div[2]/div/div[1]/table/tbody/tr[4]/td[2]/ul/li')
        colour.append(colourtag.text)
    except NoSuchElementException:
        colour.append('-')

# %%
df=pd.DataFrame({'Phone':smartphone,'RAM|ROM':ramrom,'Display':display,'Battery':battery,'Camera':camera,'Colour':colour,'Price':price,'Product Url':producturl})

# %%
df
# Out:
#                                                 Phone                 RAM|ROM  \
# 0   OnePlus Nord CE 3 Lite 5G (Chromatic Gray, 256...   8 GB RAM | 256 GB ROM
# 1     OnePlus Nord CE 3 Lite 5G (Pastel Lime, 256 GB)   8 GB RAM | 256 GB ROM
# 2            OnePlus Nord 3 5G (Tempest Gray, 128 GB)   8 GB RAM | 128 GB ROM
# 3             OnePlus Nord 3 5G (Misty Green, 128 GB)   8 GB RAM | 128 GB ROM
# 4            OnePlus Nord CE3 5G (Aqua Surge, 128 GB)   8 GB RAM | 128 GB ROM
# 5          OnePlus Nord CE3 5G (Grey Shimmer, 128 GB)   8 GB RAM | 128 GB ROM
# 6      OnePlus Nord CE 2 Lite 5G (Black Dusk, 128 GB)   6 GB RAM | 128 GB ROM
# 7       OnePlus Nord CE 2 Lite 5G (Blue Tide, 128 GB)   6 GB RAM | 128 GB ROM
# 8          OnePlus Nord CE 2 5G (Bahama Blue, 128 GB)   8 GB RAM | 128 GB ROM
# 9          OnePlus Nord CE 2 5G (Bahama Blue, 128 GB)   8 GB RAM | 128 GB ROM
# 10         OnePlus Nord CE 2 5G (Bahama Blue, 128 GB)   8 GB RAM | 128 GB ROM
# ...

# %%
df.to_csv('file1')

# %% [markdown]
# Solution 5

# %%
driver=webdriver.Chrome()

# %%
driver.get("https://www.google.com/maps")

# %%
location=driver.find_element(By.XPATH,'/html/body/div[1]/div[3]/div[8]/div[3]/div[1]/div[1]/div/div[2]/form/input')
location.send_keys('Delhi')

# %%
button=driver.find_element(By.XPATH,'/html/body/div[1]/div[3]/div[8]/div[3]/div[1]/div[1]/div/div[2]/div[1]/button')
button.click()

# %%
try:
    url_string=driver.current_url
    print("URL Exctracted: ", url_string)
    lats=re.findall(r'@(.*)data',url_string)
# Out:
#   Cell In[127], line 4
#     lats=re.findall(r'@(.*)data',url_string)
#                                             ^
# SyntaxError: incomplete input

# %% [markdown]
# Solution 6

# %%
driver=webdriver.Chrome()

# %%
driver.get("https://www.digit.in/")

# %%
click1=driver.find_element(By.XPATH,'/html/body/div[1]/header/div/div[1]/div/div/nav/ul/li[3]/a')
click1.click()

# %%
click2=driver.find_element(By.XPATH,'/html/body/div[1]/div[3]/div/div[2]/div[1]/div[3]/div[5]/p/a')
click2.click()

# %%
name=[]
os=[]
dsiplay=[]
price=[]
resolution=[]
processor=[]

# %%
nametag=driver.find_elements(By.XPATH,'//h3[@class="font130 mt0 mb10 mobilesblockdisplay "]/a')
for i in nametag:
    name.append(i.text)

# %%
# Out:
# ['ASUS Vivobook K15 OLED Ryzen 5-5500U (KM513UA-L512WS)',
#  'realme Book Prime 11th Gen Core i5-11320H (CloudPro002)',
#  'ASUS Vivobook S14 OLED S3402ZA-KM501WS 12th Gen Core i5-12500H',
#  'ASUS Vivobook Pro 16 OLED 13th Gen Core i5-13500H (K6602VU-LZ542WS)',
#  'Lenovo Yoga Slim 7i Carbon 12th Gen Core i7-1260P (82U90080IN)',
#  'Apple MacBook Pro MNEQ3HN/A (2022)',
#  'Samsung Galaxy Book3 Pro NP940XFG-KC5IN 13th Gen Core i7-1360P',
#  'Apple MacBook Pro (MK1F3HN/A)']

# %%
data=[]

# %%
data=driver.find_elements(By.XPATH,'//div[@class="woo_code_zone_loop clearbox"]')
for page in data:
    try:
        ostag=driver.find_elements(By.XPATH,'//div[@class="woo_code_zone_loop clearbox"]/div[1]/div/span[2]')
        for i in ostag:
            os.append(i.text)
    except NoSuchElementException:
        os.append('-')

# %%
# Out:
# ['Windows 11 Home',
#  'Mac Monterey',
#  'MacOS',
#  'Windows 11 Home',
#  'Mac Monterey',
#  'MacOS',
#  'Windows 11 Home',
#  'Mac Monterey',
#  'MacOS',
#  'Windows 11 Home',
#  'Mac Monterey',
#  'MacOS',
#  'Windows 11 Home',
#  'Mac Monterey',
#  'MacOS',
#  'Windows 11 Home',
#  'Mac Monterey',
#  'MacOS',
#  'Windows 11 Home',
#  'Mac Monterey',
#  'MacOS',
#  'Windows 11 Home',
#  'Mac Monterey',
#  'MacOS']

# %% [markdown]
# Solution 7

# %%
driver=webdriver.Chrome()

# %%
driver.get("http://www.forbes.com/")

# %%
btn1=driver.find_element(By.XPATH,'/html/body/div[1]/header/nav/div[1]/div[1]/div/div')
btn1.click()

# %%
btn2=driver.find_element(By.XPATH,'/html/body/div[1]/header/nav/div[1]/div[1]/div/div[2]/ul/li[2]/div[1]')
btn2.click()

# %%
btn3=driver.find_element(By.XPATH,'/html/body/div[1]/header/nav/div[1]/div[1]/div/div[2]/ul/li[2]/div[2]/div[3]/ul/li[1]/a')
btn3.click()

# %%
rank=[]
name=[]
networth=[]
age=[]
country=[]
source=[]
industry=[]

# %%
ranktag=driver.find_elements(By.XPATH,'//div[@class="Table_rank___YBhk Table_dataCell__2QCve"]')
for i in ranktag:
    rank.append(i.text)

# %%
nametag=driver.find_elements(By.XPATH,'//div[@class="TableRow_row__L-0Km"]/div[2]/div')
for i in nametag:
    name.append(i.text)

# %%
len(name)
# Out:
# 199

# %%
worthtag=driver.find_elements(By.XPATH,'//div[@class="TableRow_row__L-0Km"]/div[3]/div')
for i in worthtag:
    networth.append(i.text)

# %%
agetag=driver.find_elements(By.XPATH,'//div[@class="TableRow_row__L-0Km"]/div[4]/div')
for i in agetag:
    age.append(i.text)

# %%
sourcetag=driver.find_elements(By.XPATH,'//div[@class="TableRow_row__L-0Km"]/div[6]/div')
for i in sourcetag:
    source.append(i.text)

# %%
industrytag=driver.find_elements(By.XPATH,'//div[@class="TableRow_row__L-0Km"]/div[7]/div')
for i in industrytag:
    industry.append(i.text)

# %%
name.insert(0,'Bernard Arnault & Family')
networth.insert(0,'$211B')
age.insert(0,'74')

source.insert(0,'LVMH')
industry.insert(0,'Fashion and Retail')

# %%
len(rank),len(name),len(networth),len(age),len(source),len(industry)
# Out:
# (200, 200, 200, 200, 200, 200)

# %%
df=pd.DataFrame({'Rank':rank,'Name':name,'Networth':networth,'Age':age,'Source':source,'Industry':industry})

# %%
df
# Out:
#     Rank                      Name Networth Age              Source  \
# 0      1  Bernard Arnault & Family    $211B  74                LVMH
# 1      2                 Elon Musk   $180 B  51       Tesla, SpaceX
# 2      3                Jeff Bezos   $114 B  59              Amazon
# 3      4             Larry Ellison   $107 B  78              Oracle
# 4      5            Warren Buffett   $106 B  92  Berkshire Hathaway
# ..   ...                       ...      ...  ..                 ...
# 195  195               Jin Baofang   $9.6 B  70        Solar panels
# 196  195        Luo Liguo & family   $9.6 B  67           Chemicals
# 197  195              Marijke Mars   $9.6 B  58     Candy, pet food
# 198  195               Pamela Mars   $9.6 B  62     Candy, pet food
# 199  195              Valerie Mars   $9.6 B  64     Candy, pet food
#
#                   Industry
# 0       Fashion and Retail
# 1               Automotive
# 2               Technology
# 3               Technology
# ...

# %% [markdown]
# Solution 8

# %%
driver=webdriver.Chrome()

# %%
driver.get("https://www.youtube.com/")

# %%
video=driver.find_element(By.XPATH,'/html/body/ytd-app/div[1]/ytd-page-manager/ytd-browse/ytd-two-column-browse-results-renderer/div[1]/ytd-rich-grid-renderer/div[6]/ytd-rich-grid-row[1]/div/ytd-rich-item-renderer/div/ytd-rich-grid-media/div[1]/div[3]/div[1]/h3/a')
video.click()
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 video=driver.find_element(By.XPATH,'/html/body/ytd-app/div[1]/ytd-page-manager/ytd-browse/ytd-two-column-browse-results-renderer/div[1]/ytd-rich-grid-renderer/div[6]/ytd-rich-grid-row[1]/div/ytd-rich-item-renderer/div/ytd-rich-grid-media/div[1]/div[3]/div[1]/h3/a')
#       2 video.click()
#
# File ~\anaconda3\Lib\site-packages\selenium\webdriver\remote\webdriver.py:741, in WebDriver.find_element(self, by, value)
#     738     by = By.CSS_SELECTOR
#     739     value = f'[name="{value}"]'
# --> 741 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File ~\anaconda3\Lib\site-packages\selenium\webdriver\remote\webdriver.py:347, in WebDriver.execute(self, driver_command, params)
#     345 response = self.command_executor.execute(driver_command, params)
# ...

# %%
for _ in range(20):
    driver.execute_script("window.scrollBy(0,500)")

# %% [markdown]
# Solution 9

# %%
driver=webdriver.Chrome()

# %%
driver.get("http://www.hostelworld.com/")

# %%
city=driver.find_element(By.XPATH,'/html/body/div[3]/div/div/div[2]/div[2]/div[2]/div/div/div/div[1]/div[1]/div/div[2]/input')
city.send_keys('London')

# %%
click1=driver.find_element(By.XPATH,'/html/body/div[3]/div/div/div[2]/div[2]/div[2]/div/div/div/div[1]/div[2]/div/ul/li[2]/button')
click1.click()

# %%
button=driver.find_element(By.XPATH,'/html/body/div[3]/div/div/div[2]/div[2]/div[2]/div/div/div/div[5]/button[2]')
button.click()

# %%
name=[]
distance=[]
review=[]
private=[]
dorm=[]
facilities=[]
description=[]
hostelurl=[]

# %%
nametag=driver.find_elements(By.XPATH,'//div[@class="property-name"]/span')
for i in nametag:
    name.append(i.text)

# %%
distancetag=driver.find_elements(By.XPATH,'//span[@class="distance-description"]')
for i in distancetag:
    distance.append(i.text)

# %%
reviewtag=driver.find_elements(By.XPATH,'//div[@class="review"]')
for i in reviewtag:
    review.append(i.text)

# %%
urltag=driver.find_elements(By.XPATH,'//a[@class="nuxt-link"]')
for i in urltag:
    hostelurl.append(i.get_attribute('href'))

# %%
hostelurl.pop(0)
# Out:
# 'https://www.hostelworld.com/pwa/hosteldetails.php/St-Christopher-s-Village/London/502?from=2024-03-29&to=2024-04-01&guests=2'

# %%
for i in hostelurl:
    driver.get(i)
    time.sleep(5)
    
    try:
        desctag=driver.find_element(By.XPATH,'/html/body/div[3]/div/div/div[2]/div[2]/div[1]/div[1]/div/p')
        description.append(desctag.text)
    except NoSuchElementException:
        description.append('-')
        
     
    try:
        facilitiestag=driver.find_element(By.XPATH,'/html/body/div[3]/div/div/div[2]/div[2]/div[1]/div[5]/div/div[2]/div/div')
        facilities.append(facilitiestag.text)
    except NoSuchElementException:
        facilities.append('-')
        
        
    
    try:
        privatetag=driver.find_element(By.XPATH,'/html/body/div[3]/div/div/div[2]/div[2]/div[1]/div[2]/div/section/div/div/div[2]/div[1]/div[2]/div/div[2]/div[1]/div[1]/div[3]/div')
        private.append(privatetag.text)
    except NoSuchElementException:
        private.append('-')
        
    
    
    try:
        dormtag=driver.find_element(By.XPATH,'/html/body/div[3]/div/div/div[2]/div[2]/div[1]/div[2]/div/section/div/div/div[2]/div[2]/div[2]/div/div[2]/div[1]/div[1]/div[3]/div')
        dorm.append(dormtag.text)
    except NoSuchElementException:
        dorm.append('-')

# %%
len(name),len(distance),len(review),len(private),len(dorm),len(facilities),len(description),len(hostelurl)
# Out:
# (30, 30, 30, 30, 30, 30, 30, 30)

# %%
df=pd.DataFrame({'Name':name,'Distance':distance,'Review':review,'Price of private':private,'Price of dorm':dorm,'Facilities':facilities,'Decsription':description})

# %%
df
# Out:
#                                        Name                   Distance  \
# 0               Wombat's City Hostel London   - 3.6km from city centre
# 1                       Onefam Notting Hill   - 5.5km from city centre
# 2                      Urbany Hostel London   - 5.4km from city centre
# 3                          NX London Hostel   - 6.1km from city centre
# 4                          Generator London     - 3km from city centre
# 5                  St Christopher's Village   - 1.8km from city centre
# 6                           Onefam Waterloo   - 0.7km from city centre
# 7                        No.8 Seven Sisters     - 9km from city centre
# 8         Safestay London Elephant & Castle   - 1.7km from city centre
# 9              No.8 Willesden Hostel London    - 10km from city centre
# 10  Safestay London Kensington Holland Park   - 5.8km from city centre
# 11                          Astor Hyde Park   - 4.3km from city centre
# ...
